# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("s3://cesarmor/data/complete/iris.csv")

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
train, test=train_test_split(df, test_size=0.3, random_state=42)

# %%
train.to_csv("s3://cesarmor/data/train/iris-train.csv", index=False)

# %%
test.to_csv("s3://cesarmor/data/test/iris-test.csv", index=False)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
X_train = train.iloc [:, 0:4]

# %%
X_train
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 124           6.7          3.3           5.7          2.1
# 128           6.4          2.8           5.6          2.1
# 144           6.7          3.3           5.7          2.5
# 129           7.2          3.0           5.8          1.6
# 73            6.1          2.8           4.7          1.2
# ..            ...          ...           ...          ...
# 62            6.0          2.2           4.0          1.0
# 64            5.6          2.9           3.6          1.3
# 40            5.0          3.5           1.3          0.3
# 142           5.8          2.7           5.1          1.9
# 137           6.4          3.1           5.5          1.8
#
# [105 rows x 4 columns]

# %%
y_train = train ["variety"]

# %%
clf = DecisionTreeClassifier()

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pd.read_csv("s3://cesarmor/data/test/iris-test.csv")
# Out:
#     sepal.length  sepal.width  petal.length  petal.width     variety
# 0            6.5          3.0           5.2          2.0   Virginica
# 1            6.9          3.1           5.1          2.3   Virginica
# 2            5.4          3.4           1.7          0.2      Setosa
# 3            6.2          3.4           5.4          2.3   Virginica
# 4            6.7          3.0           5.0          1.7  Versicolor
# 5            6.0          2.9           4.5          1.5  Versicolor
# 6            6.8          2.8           4.8          1.4  Versicolor
# 7            6.2          2.9           4.3          1.3  Versicolor
# 8            5.0          3.3           1.4          0.2      Setosa
# 9            6.5          3.0           5.5          1.8   Virginica
# 10           6.1          2.8           4.0          1.3  Versicolor
# 11           5.5          2.4           3.7          1.0  Versicolor
# 12           5.8          2.8           5.1          2.4   Virginica
# 13           6.7          3.1           5.6          2.4   Virginica
# 14           4.4          3.2           1.3          0.2      Setosa
# 15           6.5          2.8           4.6          1.5  Versicolor
# 16           5.4          3.0           4.5          1.5  Versicolor
# 17           5.1          3.8           1.6          0.2      Setosa
# 18           4.9          2.4           3.3          1.0  Versicolor
# 19           5.0          2.3           3.3          1.0  Versicolor
# 20           5.7          2.8           4.5          1.3  Versicolor
# 21           7.7          2.6           6.9          2.3   Virginica
# 22           4.5          2.3           1.3          0.3      Setosa
# 23           7.7          3.8           6.7          2.2   Virginica
# 24           6.0          2.2           5.0          1.5   Virginica
# 25           5.2          3.4           1.4          0.2      Setosa
# 26           6.3          2.5           4.9          1.5  Versicolor
# 27           7.2          3.2           6.0          1.8   Virginica
# 28           5.0          3.2           1.2          0.2      Setosa
# 29           4.7          3.2           1.3          0.2      Setosa
# 30           5.0          3.5           1.6          0.6      Setosa
# 31           6.4          2.7           5.3          1.9   Virginica
# 32           6.3          2.9           5.6          1.8   Virginica
# 33           4.8          3.4           1.9          0.2      Setosa
# 34           5.8          2.7           4.1          1.0  Versicolor
# 35           5.4          3.9           1.7          0.4      Setosa
# 36           6.9          3.2           5.7          2.3   Virginica
# 37           5.5          2.3           4.0          1.3  Versicolor
# 38           6.2          2.8           4.8          1.8   Virginica
# 39           5.0          3.6           1.4          0.2      Setosa
# 40           4.8          3.0           1.4          0.1      Setosa
# 41           5.5          4.2           1.4          0.2      Setosa
# 42           5.1          3.3           1.7          0.5      Setosa
# 43           4.9          2.5           4.5          1.7   Virginica
# 44           5.0          3.4           1.5          0.2      Setosa
